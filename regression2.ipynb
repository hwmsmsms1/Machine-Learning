# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./Datasets/USA_Housing.csv')
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 10%        55047.633980             4.697755                   5.681951
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# 90%        82081.188283             7.243978                   8.274222
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# ...

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
df['Price'].plot.hist(bins=25, figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Price'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df.corr()
# Out:
# C:\Users\hmins\AppData\Local\Temp\ipykernel_4320\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), cmap='Reds',annot=True, linewidths=2)
# Out:
# C:\Users\hmins\AppData\Local\Temp\ipykernel_4320\317405575.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='Reds',annot=True, linewidths=2)
# <Axes: >

# %%
l_column = list(df.columns)
len_feature = len(l_column)
l_column
# Out:
# ['Avg. Area Income',
#  'Avg. Area House Age',
#  'Avg. Area Number of Rooms',
#  'Avg. Area Number of Bedrooms',
#  'Area Population',
#  'Price',
#  'Address']

# %%
# Price, Address 제거

X=df[l_column[0:len_feature-2]]
y=df[l_column[len_feature-2]]

# %%
print("Feature set size :", X.shape)
print('Variable set size :', y.shape)
# Out:
# Feature set size : (5000, 5)
# Variable set size : (5000,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print('Training feature set size :', X_train.shape)
print('Test feature set size :', X_test.shape)
print('Training variable set size :', y_train.shape)
print('Test variable set size :', y_test.shape)
# Out:
# Training feature set size : (3500, 5)
# Test feature set size : (1500, 5)
# Training variable set size : (3500,)
# Test variable set size : (1500,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("The intercept term of the linear model:", lm.intercept_)
# Out:
# The intercept term of the linear model: -2645289.864342203

# %%
print('The coefficients of the linear model :', lm.coef_)
# Out:
# The coefficients of the linear model : [2.16398550e+01 1.65729214e+05 1.20958349e+05 1.94909254e+03
#  1.52262240e+01]

# %%
cdf = pd.DataFrame(data=lm.coef_, index=X_train.columns, columns=['Coefficients'])
# Out:
#                                Coefficients
# Avg. Area Income                  21.639855
# Avg. Area House Age           165729.214008
# Avg. Area Number of Rooms     120958.348945
# Avg. Area Number of Bedrooms    1949.092538
# Area Population                   15.226224

# %%
n = X_train.shape[0]
k = X_train.shape[1]
dfN = n-k

train_pred = lm.predict(X_train)
train_error = np.square(train_pred - y_train)
sum_error=np.sum(train_error)
se=[0,0,0,0,0]

for i in range(k):
    r=(sum_error/dfN)
    r=r/np.sum(np.square(X_train[list(X_train.columns)[i]] - X_train[list(X_train.columns)[i]].mean()))
    se[i]=np.sqrt(r)

cdf['Standard Error'] = se
cdf['T-statistic'] = cdf['Coefficients']/cdf['Standard Error']
cdf
# Out:
#                                Coefficients  Standard Error  T-statistic
# Avg. Area Income                  21.639855        0.160414   134.900410
# Avg. Area House Age           165729.214008     1704.129477    97.251539
# Avg. Area Number of Rooms     120958.348945     1695.829982    71.326932
# Avg. Area Number of Bedrooms    1949.092538     1381.581112     1.410770
# Area Population                   15.226224        0.171413    88.827819

# %%
l = list(cdf.sort_values('T-statistic', ascending=False).index)
print(' > \n'.join(l))
# Out:
# Avg. Area Income >
# Avg. Area House Age >
# Area Population >
# Avg. Area Number of Rooms >
# Avg. Area Number of Bedrooms

# %%
l=list(cdf.index)
from matplotlib import gridspec
fig=plt.figure(figsize=(18, 10))
gs=gridspec.GridSpec(2,3)

ax0=plt.subplot(gs[0])
ax0.scatter(df[l[0]], df['Price'])
ax0.set_title(l[0]+" vs. Price", fontdict={'fontsize':15})

ax1=plt.subplot(gs[1])
ax1.scatter(df[l[1]], df['Price'])
ax1.set_title(l[1]+" vs. Price", fontdict={'fontsize':15})

ax2=plt.subplot(gs[2])
ax2.scatter(df[l[2]], df['Price'])
ax2.set_title(l[2]+" vs. Price", fontdict={'fontsize':15})

ax3=plt.subplot(gs[3])
ax3.scatter(df[l[3]], df['Price'])
ax3.set_title(l[3]+' vs. Price', fontdict={'fontsize':15})

ax4=plt.subplot(gs[4])
ax4.scatter(df[l[4]], df['Price'])
ax4.set_title(l[4]+' vs. Price', fontdict={'fontsize':15})
# Out:
# Text(0.5, 1.0, 'Area Population vs. Price')

# %%
print('R-squared value :', round(metrics.r2_score(y_train, train_pred),3))
# Out:
# R-squared value : 0.919

# %%
predictions=lm.predict(X_test)
print("Type of the predicted object :", type(predictions))
print("Size of the predicted object :", predictions.shape)
# Out:
# Type of the predicted object : <class 'numpy.ndarray'>
# Size of the predicted object : (1500,)

# %%
plt.figure(figsize=(10,7))
plt.title("Actual vs. predicted house prices", fontsize=25)
plt.xlabel("Actual test set house prices", fontsize=18)
plt.ylabel("Predicted house prices", fontsize=18)
plt.scatter(x=y_test, y=predictions)

# %%
plt.figure(figsize=(10,7))
plt.title("Histogram of residuals to check for normality", fontsize=25)
plt.xlabel("Residuals", fontsize=18)
plt.ylabel("Kernel density", fontsize=18)
sns.distplot([y_test-predictions])
# Out:
# C:\Users\hmins\AppData\Local\Temp\ipykernel_4320\1211609078.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([y_test-predictions])
# <Axes: title={'center': 'Histogram of residuals to check for normality'}, xlabel='Residuals', ylabel='Kernel density'>

# %%
plt.figure(figsize=(10,7))
plt.title("Residuals vs. predicted values plot (Homoscedasticity)")
plt.xlabel("Predicted house prices", fontsize=18)
plt.ylabel("Residuals", fontsize=18)
plt.scatter(x=predictions, y=y_test-predictions)

# %% [markdown]
# ### 잔차/예측값 산포도 등분산성 모양
#
# ![nn](./Datasets/homoscedasticity.png)

# %%
print("Mean absolute error (MAE) :", metrics.mean_absolute_error(y_test,predictions))
print("Mean square error (MSE) :", metrics.mean_squared_error(y_test,predictions))
print("Root mean square error (RMSE) :", np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# Mean absolute error (MAE) : 82745.90894156111
# Mean square error (MSE) : 10567448570.930307
# Root mean square error (RMSE) : 102798.0961444827

# %%
print("R-squared :", round(metrics.r2_score(y_test,predictions),3))
# Out:
# R-squared : 0.917

# %% [markdown]
# * plot.kde = plot.density
# >  histogram을 smoothing 하는 작업, 둘이 같음
# * sns.heatmap 에서 cmap = 'Colors' 로 색상변경 가능
# ------------
# * lm.intercept_ : feature y절편, 편향, 얼마나 치우쳐있는가
# * lm.coef_ : feature 기울기
# -----------
# * sns.distplot : 히스토그램 + kde(커널밀도함수) 같이 나옴
# -----------
# * y_test - prediction = Residual ( 잔차 )
# -------------
# * homoscedasticity ( 등분산성 )
# > - 회귀식에 의한 예측값과 종속변수의 오차(Error or Residual)는 분산이 같아야 한다
# > - 다를 경우 실제 데이터 예측에 문제 생김
# > - 비교하는 집단과 동일한 집단인지 아닌지 즉, 통계적으로 같은 집단으로 판단이 되어지는 아닌지를 파악하는 기법
